# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


df1=pd.read_csv("properatti.csv",delimiter=",")
df1=df1.drop(["Unnamed: 0"], axis=1)
df1
# Out:
#        operation property_type       place_name  \
# 0           sell            PH        Mataderos
# 1           sell     apartment         La Plata
# 2           sell     apartment        Mataderos
# 3           sell            PH          Liniers
# 4           sell     apartment           Centro
# ...          ...           ...              ...
# 121215      sell     apartment         Belgrano
# 121216      sell         house           Beccar
# 121217      sell     apartment    Villa Urquiza
# 121218      sell     apartment      Plaza Colón
# 121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 3                     |Argentina|Capital Federal|Liniers|    Argentina
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121220 entries, 0 to 121219
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   operation                   121220 non-null  object
#  1   property_type               121220 non-null  object
#  2   place_name                  121197 non-null  object
#  3   place_with_parent_names     121220 non-null  object
#  4   country_name                121220 non-null  object
#  5   state_name                  121220 non-null  object
#  6   geonames_id                 102503 non-null  float64
#  7   lat-lon                     69670 non-null   object
#  8   lat                         69670 non-null   float64
#  9   lon                         69670 non-null   float64
#  10  price                       100810 non-null  float64
#  11  currency                    100809 non-null  object
# ...

# %%
df1.head()
df1[1110:1115]
# Out:
#      operation property_type place_name               place_with_parent_names  \
# 1110      sell     apartment   Belgrano  |Argentina|Capital Federal|Belgrano|
# 1111      sell     apartment   Belgrano  |Argentina|Capital Federal|Belgrano|
# 1112      sell     apartment   Belgrano  |Argentina|Capital Federal|Belgrano|
# 1113      sell     apartment   Belgrano  |Argentina|Capital Federal|Belgrano|
# 1114      sell     apartment   Belgrano  |Argentina|Capital Federal|Belgrano|
#
#      country_name       state_name  geonames_id                  lat-lon  \
# 1110    Argentina  Capital Federal    3436077.0  -34.5621876,-58.4430869
# 1111    Argentina  Capital Federal    3436077.0  -34.5621876,-58.4430869
# 1112    Argentina  Capital Federal    3436077.0  -34.5621876,-58.4430869
# 1113    Argentina  Capital Federal    3436077.0  -34.5621876,-58.4430869
# 1114    Argentina  Capital Federal    3436077.0  -34.5621876,-58.4430869
#
# ...

# %%
df1.tail()
# Out:
#        operation property_type       place_name  \
# 121215      sell     apartment         Belgrano
# 121216      sell         house           Beccar
# 121217      sell     apartment    Villa Urquiza
# 121218      sell     apartment      Plaza Colón
# 121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 121215               Capital Federal    3436077.0
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0
# 121217               Capital Federal    3433775.0
# ...

# %%
print(df1.columns)
# Out:
# Index(['operation', 'property_type', 'place_name', 'place_with_parent_names',
#        'country_name', 'state_name', 'geonames_id', 'lat-lon', 'lat', 'lon',
#        'price', 'currency', 'price_aprox_local_currency', 'price_aprox_usd',
#        'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2',
#        'price_per_m2', 'floor', 'rooms', 'expenses', 'properati_url',
#        'description', 'title', 'image_thumbnail'],
#       dtype='object')

# %%
df1.describe()
# Out:
#         geonames_id           lat           lon         price  \
# count  1.025030e+05  69670.000000  69670.000000  1.008100e+05
# mean   3.574442e+06    -34.626210    -59.266290  4.685259e+05
# std    3.541306e+05      1.980936      2.299922  2.260101e+06
# min    3.427208e+06    -54.823985    -75.678931  0.000000e+00
# 25%    3.430234e+06    -34.669065    -58.727040  1.100000e+05
# 50%    3.433910e+06    -34.597985    -58.480128  1.850000e+05
# 75%    3.836668e+06    -34.441299    -58.395908  4.200000e+05
# max    6.948895e+06      4.545843    -53.733330  6.500000e+08
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# count                1.008100e+05     1.008100e+05         81892.000000
# mean                 4.229397e+06     2.397006e+05           233.795328
# std                  6.904714e+06     3.913239e+05          1782.222147
# min                  0.000000e+00     0.000000e+00             0.000000
# ...

# %%
df1.isna().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                        23
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    18717
# lat-lon                        51550
# lat                            51550
# lon                            51550
# price                          20410
# currency                       20411
# price_aprox_local_currency     20410
# price_aprox_usd                20410
# surface_total_in_m2            39328
# surface_covered_in_m2          19907
# price_usd_per_m2               52603
# price_per_m2                   33562
# floor                         113321
# rooms                          73830
# expenses                      106958
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 3112
# dtype: int64

# %%
total_col= np.product(df1.shape)
mv1= mv.sum()
(mv1/total_col)*100
# Out:
# 23.021085629434086

# %%
df1=df1.dropna(subset=["price"])
df1
# Out:
#        operation property_type       place_name  \
# 0           sell            PH        Mataderos
# 1           sell     apartment         La Plata
# 2           sell     apartment        Mataderos
# 3           sell            PH          Liniers
# 4           sell     apartment           Centro
# ...          ...           ...              ...
# 121215      sell     apartment         Belgrano
# 121216      sell         house           Beccar
# 121217      sell     apartment    Villa Urquiza
# 121218      sell     apartment      Plaza Colón
# 121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 3                     |Argentina|Capital Federal|Liniers|    Argentina
# ...

# %%
suelo=pd.get_dummies(df1["floor"]).sum().sort_values(ascending=False)
suelo.tail()
# Out:
# 248.0     1
# 205.0     1
# 201.0     1
# 181.0     1
# 2509.0    1
# dtype: int64

# %%
suelo1=suelo.replace([2509,181],np.nan)
suelo1
# Out:
# 1.0       1828
# 2.0       1385
# 3.0        820
# 4.0        559
# 5.0        408
#           ...
# 248.0        1
# 205.0        1
# 201.0        1
# 181.0        1
# 2509.0       1
# Length: 174, dtype: int64

# %%
df1["surface_covered_in_m2"].sort_values(ascending=False)
# Out:
# 76012     187000.0
# 35151      49000.0
# 39221      38240.0
# 106376     30000.0
# 44245      27853.0
#             ...
# 121203         NaN
# 121204         NaN
# 121205         NaN
# 121206         NaN
# 121209         NaN
# Name: surface_covered_in_m2, Length: 100810, dtype: float64

# %%
df1[["surface_total_in_m2","surface_covered_in_m2"]].tail()
# Out:
#         surface_total_in_m2  surface_covered_in_m2
# 121215                113.0                   93.0
# 121216                360.0                  360.0
# 121217                 46.0                   39.0
# 121218                 48.0                   48.0
# 121219                 77.0                   77.0

# %%
df1["surface_covered_in_m2"].value_counts()
# Out:
# 40.0       2736
# 50.0       2184
# 45.0       2142
# 60.0       1888
# 100.0      1848
#            ...
# 705.0         1
# 891.0         1
# 14000.0       1
# 835.0         1
# 12000.0       1
# Name: surface_covered_in_m2, Length: 995, dtype: int64

# %%
df1.dropna(subset=["surface_total_in_m2","surface_covered_in_m2"])
# Out:
#        operation property_type       place_name  \
# 0           sell            PH        Mataderos
# 2           sell     apartment        Mataderos
# 4           sell     apartment           Centro
# 6           sell            PH            Munro
# 7           sell     apartment         Belgrano
# ...          ...           ...              ...
# 121215      sell     apartment         Belgrano
# 121216      sell         house           Beccar
# 121217      sell     apartment    Villa Urquiza
# 121218      sell     apartment      Plaza Colón
# 121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 6       |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# ...

# %%
df1[["surface_covered_in_m2","surface_total_in_m2"]].dropna(how="all")
# Out:
#         surface_covered_in_m2  surface_total_in_m2
# 0                        40.0                 55.0
# 2                        55.0                 55.0
# 4                        35.0                 35.0
# 5                         NaN                 53.0
# 6                        78.0                106.0
# ...                       ...                  ...
# 121215                   93.0                113.0
# 121216                  360.0                360.0
# 121217                   39.0                 46.0
# 121218                   48.0                 48.0
# 121219                   77.0                 77.0
#
# [108851 rows x 2 columns]

# %%
no_dat_mts=no_dat_mts.dropna(how="all")
no_dat_mts.head(20)
# Out:
#     surface_covered_in_m2  surface_total_in_m2
# 0                    40.0                 55.0
# 2                    55.0                 55.0
# 4                    35.0                 35.0
# 5                     NaN                 53.0
# 6                    78.0                106.0
# 7                    40.0                 45.0
# 8                    60.0                 65.0
# 10                    NaN               1514.0
# 12                   36.0                 39.0
# 13                   30.0                 50.0
# 14                   31.0                 42.0
# 15                    NaN                164.0
# 16                   98.0                140.0
# 17                   78.0                176.0
# 18                  270.0                270.0
# 19                   96.0                104.0
# 20                  148.0                148.0
# 21                   73.0                118.0
# 22                  200.0                200.0
# ...

# %%
pd.get_dummies(df1["property_type"])
# Out:
#         PH  apartment  house  store
# 0        1          0      0      0
# 1        0          1      0      0
# 2        0          1      0      0
# 3        1          0      0      0
# 4        0          1      0      0
# ...     ..        ...    ...    ...
# 121215   0          1      0      0
# 121216   0          0      1      0
# 121217   0          1      0      0
# 121218   0          1      0      0
# 121219   0          1      0      0
#
# [121220 rows x 4 columns]

# %%
df1df1["price"].dropna()
# Out:
# 0          62000.0
# 1         150000.0
# 2          72000.0
# 3          95000.0
# 4          64000.0
#             ...
# 121215    870000.0
# 121216    498000.0
# 121217    131500.0
# 121218     95900.0
# 121219    129000.0
# Name: price, Length: 100810, dtype: float64

# %%
df1.describe(include=["O"])
# Out:
#        operation property_type place_name       place_with_parent_names  \
# count     121220        121220     121197                        121220
# unique         1             4       1060                          1164
# top         sell     apartment    Córdoba  |Argentina|Santa Fe|Rosario|
# freq      121220         71065       9254                          8504
#
#        country_name       state_name                  lat-lon currency  \
# count        121220           121220                    69670   100809
# unique            1               28                    47203        4
# top       Argentina  Capital Federal  -34.4026444,-58.6684776      USD
# freq         121220            32316                      312    87587
#
#                                             properati_url  \
# count                                              121220
# unique                                             121220
# top     http://www.properati.com.ar/15bo8_venta_ph_mat...
# ...

# %%
df1.ix[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df1.ix[2]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
